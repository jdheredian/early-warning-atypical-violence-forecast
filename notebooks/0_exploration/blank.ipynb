# %%
import pandas as pd

# %%
(
    pd.read_parquet("/Users/juandiegoheredianino/Library/CloudStorage/OneDrive-Universidaddelosandes/early-warning-atypical-violence-forecast/data/processed/iacv_index.parquet")[['mun_code', 'quarter', 'qty_01', 'qty_02', 'qty_03', 'qty_04', 'qty_05']]
    .rename(columns={'qty_01':'Homicidio','qty_02':'Secuestro','qty_03':'Terrorismo','qty_04':'Extorsión','qty_05':'Masacres'})
    .to_excel("/Users/juandiegoheredianino/Library/CloudStorage/OneDrive-Universidaddelosandes/early-warning-atypical-violence-forecast/data/processed/violencia.xlsx", index=False)
    )
